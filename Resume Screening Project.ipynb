# %%
# Core libraries
import pandas as pd
import numpy as np
import re

# NLP & ML libraries
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
# Load resume dataset
df = pd.read_csv(r"C:\Users\user\Music\RESUME PROJECT\UpdatedResumeDataSet.csv")

print("Dataset shape:", df.shape)
print("Columns:", df.columns)
# Out:
# Dataset shape: (962, 2)
# Columns: Index(['Category', 'Resume'], dtype='object')

# %%
# TEXT CLEANING FUNCTION
def clean_text(text):
    """
    Cleans resume text by:
    - Lowercasing
    - Removing punctuation
    - Removing extra spaces
    """
    text = str(text).lower()
    text = re.sub(r'\n', ' ', text)
    text = re.sub(r'[^\w\s]', '', text)
    text = re.sub(r'\s+', ' ', text).strip()
    return text

# %%
# Apply cleaning
df['Cleaned_Resume'] = df['Resume'].apply(clean_text)

print(df['Cleaned_Resume'][0][:500])
# Out:
# skills programming languages python pandas numpy scipy scikitlearn matplotlib sql java javascriptjquery machine learning regression svm naãve bayes knn random forest decision trees boosting techniques cluster analysis word embedding sentiment analysis natural language processing dimensionality reduction topic modelling lda nmf pca neural nets database visualizations mysql sqlserver cassandra hbase elasticsearch d3js dcjs plotly kibana matplotlib ggplot tableau others regular expression html css

# %%
#DEFINE SKILL SET
skills_list = [
    'python', 'sql', 'machine learning', 'ml', 'deep learning',
    'nlp', 'natural language processing',
    'pandas', 'numpy', 'scikit learn',
    'tensorflow', 'keras',
    'matplotlib', 'seaborn'
]

# %%
# SKILL EXTRACTION FUNCTION
def extract_skills(text):
    """
    Extracts matching skills from resume text
    """
    found_skills = []
    for skill in skills_list:
        if skill in text:
            found_skills.append(skill)
    return list(set(found_skills))

# %%
df['Skills_Found'] = df['Cleaned_Resume'].apply(extract_skills)
df['Skill_Score'] = df['Skills_Found'].apply(len)

# %%
# JOB DESCRIPTION INPUT
job_description = """
Looking for a Data Scientist with strong Python, SQL,
Machine Learning, NLP, Pandas, NumPy and data visualization skills.
"""

job_description_clean = clean_text(job_description)

# %%
# TF-IDF + COSINE SIMILARITY
# Combine resumes + job description
all_texts = df['Cleaned_Resume'].tolist() + [job_description_clean]

# TF-IDF Vectorization
tfidf = TfidfVectorizer(stop_words='english')
tfidf_matrix = tfidf.fit_transform(all_texts)

# Similarity between resumes & JD
similarity_scores = cosine_similarity(
    tfidf_matrix[:-1], tfidf_matrix[-1]
).flatten()

df['Text_Similarity'] = similarity_scores

# %%
#COMBINED SCORE
df['Combined_Score'] = (
    0.6 * df['Text_Similarity'] +
    0.4 * (df['Skill_Score'] / df['Skill_Score'].max())
)

# %%
#FINAL RANKING
final_df = df[['Category', 'Skills_Found', 'Skill_Score',
               'Text_Similarity', 'Combined_Score']].copy()

final_df['Rank'] = final_df['Combined_Score'].rank(
    ascending=False, method='dense'
)

final_df = final_df.sort_values(by='Combined_Score', ascending=False)

final_df.head(30)
# Out:
#              Category                                       Skills_Found  \
# 37       Data Science  [numpy, keras, pandas, machine learning, matpl...
# 7        Data Science  [numpy, keras, pandas, machine learning, matpl...
# 27       Data Science  [numpy, keras, pandas, machine learning, matpl...
# 17       Data Science  [numpy, keras, pandas, machine learning, matpl...
# 8        Data Science  [numpy, pandas, machine learning, deep learnin...
# 38       Data Science  [numpy, pandas, machine learning, deep learnin...
# 18       Data Science  [numpy, pandas, machine learning, deep learnin...
# 28       Data Science  [numpy, pandas, machine learning, deep learnin...
# 10       Data Science  [numpy, pandas, machine learning, matplotlib, ...
# 20       Data Science  [numpy, pandas, machine learning, matplotlib, ...
# 30       Data Science  [numpy, pandas, machine learning, matplotlib, ...
# 0        Data Science  [numpy, pandas, machine learning, matplotlib, ...
# 36       Data Science                         [machine learning, python]
# 26       Data Science                         [machine learning, python]
# 6        Data Science                         [machine learning, python]
# 16       Data Science                         [machine learning, python]
# 23       Data Science  [machine learning, deep learning, nlp, sql, py...
# 3        Data Science  [machine learning, deep learning, nlp, sql, py...
# 13       Data Science  [machine learning, deep learning, nlp, sql, py...
# 33       Data Science  [machine learning, deep learning, nlp, sql, py...
# 29       Data Science                    [nlp, machine learning, python]
# 9        Data Science                    [nlp, machine learning, python]
# 39       Data Science                    [nlp, machine learning, python]
# 19       Data Science                    [nlp, machine learning, python]
# 31       Data Science              [machine learning, python, keras, ml]
# 11       Data Science              [machine learning, python, keras, ml]
# 21       Data Science              [machine learning, python, keras, ml]
# 1        Data Science              [machine learning, python, keras, ml]
# 583  Python Developer                   [tensorflow, numpy, python, sql]
# 589  Python Developer                   [tensorflow, numpy, python, sql]
#
#      Skill_Score  Text_Similarity  Combined_Score  Rank
# 37            13         0.244761        0.546857   1.0
# 7             13         0.244761        0.546857   1.0
# 27            13         0.244761        0.546857   1.0
# 17            13         0.244761        0.546857   1.0
# 8              8         0.260321        0.402347   2.0
# 38             8         0.260321        0.402347   2.0
# 18             8         0.260321        0.402347   2.0
# 28             8         0.260321        0.402347   2.0
# 10             9         0.096855        0.335036   3.0
# 20             9         0.096855        0.335036   3.0
# 30             9         0.096855        0.335036   3.0
# 0              9         0.096855        0.335036   3.0
# 36             2         0.337952        0.264309   4.0
# 26             2         0.337952        0.264309   4.0
# 6              2         0.337952        0.264309   4.0
# 16             2         0.337952        0.264309   4.0
# 23             6         0.101682        0.245625   5.0
# 3              6         0.101682        0.245625   5.0
# 13             6         0.101682        0.245625   5.0
# 33             6         0.101682        0.245625   5.0
# 29             3         0.238894        0.235644   6.0
# 9              3         0.238894        0.235644   6.0
# 39             3         0.238894        0.235644   6.0
# 19             3         0.238894        0.235644   6.0
# 31             4         0.136885        0.205208   7.0
# 11             4         0.136885        0.205208   7.0
# 21             4         0.136885        0.205208   7.0
# 1              4         0.136885        0.205208   7.0
# 583            4         0.125794        0.198553   8.0
# 589            4         0.125794        0.198553   8.0
